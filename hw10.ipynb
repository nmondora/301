# %%
import sympy
import control
import matplotlib.pyplot as plt

# %% [markdown]
# # homework 10 Nick Mondora

# %% [markdown]
# ## question 1

# %%
s = control.tf([1, 0], [0, 1])

# %%
G_D = ((18*s)*(s-3)) / ((s+1)*(s+2))
control.bode(G_D, dB=True);
G_D
# Out:
# TransferFunction(array([ 18., -54.,   0.]), array([1., 3., 2.]))
